# %%
import pip

if int(pip.__version__.split('.')[0])>9:
    from pip._internal import main
else:
    from pip import main
    
def install(package):
    main(['install', package])

install('BeautifulSoup4')
install('numpy')
install('pandas')
install('matplotlib')
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: BeautifulSoup4 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from BeautifulSoup4) (2.5)
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (2.0.1)
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/will.spurgin/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
# Out:
# WARNING: Matplotlib is building the font cache; this may take a moment.
# Failed to extract font properties from /System/Library/Fonts/Supplemental/NISC18030.ttf: In FT2Font: Could not set the fontsize (invalid pixel size; error code 0x17)
# Failed to extract font properties from /System/Library/Fonts/Apple Color Emoji.ttc: In FT2Font: Could not set the fontsize (invalid pixel size; error code 0x17)
# Failed to extract font properties from /System/Library/Fonts/LastResort.otf: tuple indices must be integers or slices, not str
# generated new fontManager

# %%
seasons = [2018, 2019, 2020, 2021, 2022, 2023]
weeks = range(1, 17)
pos = {
    "D/ST": 99,
    "RB": 20,
    "WR": 30,
    "QB": 10
}
sample_url = 'https://www.fftoday.com/stats/playerstats.php?Season=2018&GameWeek=1&PosID=99&LeagueID=143908'

url_build = "https://www.fftoday.com/stats/playerstats.php?Season={season}&GameWeek={week}&PosID={pos}&LeagueID=143908"


def positionDataScrape(pos):
    data = []
    for season in seasons:
         for week in weeks:
            data += scrapePosBySeasonWeek(pos, season, week)
    sys.stdout.flush()
    return data

def scrapePosBySeasonWeek(pos, season, week):
    data = []
    url = url_build.format(season=season, week=week, pos=pos)
    sys.stdout.write("\rScrapping {}\t\t".format(url))

    stat_page = urlopen(url)
    stat_soup = BeautifulSoup(stat_page, 'html.parser')
    header = stat_soup.find('tr', class_='tableclmhdr')
    group_header = stat_soup.find('tr', class_='tablehdr')
    rows = header.find_next_siblings('tr')

    group_headers = []
    next_header_index = 0
    for td in group_header.find_all('td')[:-1]: # All group headers minus the last one which is always "Fantasy"
        num_headers = int(td['colspan'])
        group = { 'name': td.get_text().strip(), 'num_headers': num_headers, 'offset': next_header_index }
        group_headers.append(group)
        next_header_index += num_headers

    keys = []
    for td in header.find_all('td'):
        keys.append(td.get_text().strip())

    for group in group_headers:
        if group["name"] == '':
            continue
        span = slice(group['offset'], group['offset'] + group['num_headers'])
        keys[span] = ["{} - {}".format(group['name'], k) for k in keys[span]]


    keys.append('Season')
    keys.append('Week')


    for tr in rows:
        game = {k:None for k in keys}
        i = 0
        for td in tr.find_all('td'):
            game[keys[i]] = td.get_text().strip()
            i += 1
        game['Season'] = season
        game['Week'] = week
        game[keys[0]] = re.sub('^[\W\d]+', '', game[keys[0]])
        game[keys[0]] = re.sub('[\n\r\t]+', '', game[keys[0]])
        game[keys[0]] = re.sub('(s|S)ort\s', '', game[keys[0]]) # Remove the word "sort"
        data.append(game)
        
    return data

def customDefScoring(game):
    score = 0.0
    score += standardDefPts(game)
    if game['PA'] == 0:
        score += 20
    elif game['PA'] <= 6:
        score += 15
    elif game['PA'] <= 13:
        score += 10
    elif game['PA'] <= 20:
        score += 5
    elif game['PA'] <= 27:
        score += 0
    elif game['PA'] <= 34:
        score += -5
    elif game['PA'] >= 35:
        score += -10

    return score

def standardDefPts(game):
    return (1 * game['Sack']) + (2 * game['INT']) + (6 * game['DefTD']) + (6 * game['KickTD']) + (2 * game['Safety'])

# %%
data = positionDataScrape(pos["D/ST"])
# Out:
# Scrapping https://www.fftoday.com/stats/playerstats.php?Season=2023&GameWeek=16&PosID=99&LeagueID=143908

# %%
df = pd.DataFrame(data)
df = df.astype({k:'float64' for k in df.columns[1:-2]})

# %%
df['CustFPts'] = df.apply(customDefScoring, axis=1)
df['ProposedCustFPts'] = df.apply(customDefScoring, axis=1)

# %%
wr_data = positionDataScrape(pos['WR'])
# Out:
# Scrapping https://www.fftoday.com/stats/playerstats.php?Season=2023&GameWeek=16&PosID=30&LeagueID=143908

# %%
wr_df = pd.DataFrame(wr_data)
wr_df = wr_df.astype({k:'float64' for k in wr_df.columns[2:-2]})

# %%
rb_data = positionDataScrape(pos['RB'])
rb_df = pd.DataFrame(rb_data)
rb_df = rb_df.astype({k:'float64' for k in rb_df.columns[2:-2]})
# Out:
# Scrapping https://www.fftoday.com/stats/playerstats.php?Season=2023&GameWeek=16&PosID=20&LeagueID=143908

# %%
qb_data = positionDataScrape(pos['QB'])
qb_df = pd.DataFrame(qb_data)
qb_df = qb_df.astype({k:'float64' for k in qb_df.columns[2:-2]})
# Out:
# Scrapping https://www.fftoday.com/stats/playerstats.php?Season=2023&GameWeek=16&PosID=10&LeagueID=143908

# %%
qb_df['CustFPts'] = qb_df.apply(lambda game: game['FPts'] + (game['Passing - INT'] * -1) + (game['Passing - TD'] * 2) + (game['Passing - Yard'] * 0.04), axis=1)
# qb_df['CustFPts'] = qb_df.apply(lambda game: (game['Passing - INT'] * -3) + (game['Passing - TD'] * 6) + (game['Passing - Yard'] * 0.05) + (game['Rushing - Yard'] * 0.01) + (game['Rushing - TD'] * 6), axis=1)

# %%
# Update column names to strip out all the weird values.
qb_df.columns.values[0] = 'Player'
wr_df.columns.values[0] = 'Player'
rb_df.columns.values[0] = 'Player'

# Recomputes helper methods for us
qb_df.columns = qb_df.columns.values
wr_df.columns = wr_df.columns.values
rb_df.columns = rb_df.columns.values

# %% [markdown]
# # Playing for Keeps - Custom Scoring System
#
# ## TL;DR
#
# The goal of the league was to have a fantasy league that was more like the NFL. To do this, we implemented new league rules, like trading draft picks and having keepers, and scoring rule changes. These scoring rules had 2 goals:
#
# - Make fantasy scoring easier to keep track of while on the couch
#     - QB passing touchdowns are 6 points (instead of 4)
#     - QB passing yards are a half point for every 10 yards (instead of .4 points per 10 yards)
#     - Kickers are 3 points for any field goal (instead of distance affecting points)
#     - Defenses start at 28 points. Every time the opponent scores a touchdown, your defense loses a touchdown (7 points) from the starting score.
# - Make fantasy points more equal to real life value
#     - Increased scoring for QBs makes them the highest scoring, thus ‘most valuable’ player on the field
#     - Increased scoring for defenses made them similar in value to a QB, as defense is half of the NFL
#
# For Defensive scoring, points allowed is the main driver for points:
#
# - 0 points allowed: 	20 points
# - 1-6 points allowed: 	15 points
# - 7-13 points allowed: 	10 points
# - 14-20 points allowed: 5 points
# - 21-27 points allowed: 0 points
# - 28-34 points allowed: -5 points
# - 35+ points allowed: 	-10 points
#
# All other defensive scoring rules follow standard scoring.
#
# You can look at the [stats section](#stats-appendix) for all the info we have on the current D/ST scoring (including team by team stats by season).

# %%
df.CustFPts.hist()
plt.title("D/ST Custom Playing-for-Keeps Scoring")
plt.vlines(df.CustFPts.mean(), 0, 800, ['r'], 'dashed', 'avg')
plt.xlabel("Score")
plt.ylabel("# of player games")
# Out:
# Text(0, 0.5, '# of player games')

# %%
df.where(df.PA == 0)[['FPts', 'CustFPts']].describe(percentiles=[0.25,0.50,0.75,0.90])
# Out:
#             FPts   CustFPts
# count  31.000000  31.000000
# mean   10.645161  29.096774
# std     4.956803   5.204836
# min     3.000000  21.000000
# 25%     7.000000  25.000000
# 50%    11.000000  29.000000
# 75%    13.000000  31.000000
# 90%    15.000000  33.000000
# max    27.000000  47.000000

# %% [markdown]
# ### Volatility in D/ST fantasy points
#
# In stats, "volatility" this is called "standard deviation". Typically, standard deviation is a good indicator of "volatility". If the standard deviation is way higher than the average (aka the "mean"), then getting a score near the average is very "uncertain".
#
# It's easier if we visualize it:

# %%
df_avg = df.CustFPts.mean()
df_std = df.CustFPts.std()
df.CustFPts.hist()
plt.title("D/ST Custom Playing-for-Keeps Scoring")
plt.vlines([df_avg, df_avg + df_std, df_avg - df_std], 0, 800, ['r', 'c', 'c'], ['dashed', 'dashdot', 'dashdot'])
plt.xlabel("Score")
plt.ylabel("# of player games")
# Out:
# Text(0, 0.5, '# of player games')

# %% [markdown]
# The red line in the middle is the average, the cyan lines on either side are "1 standard deviation" away from the average. The wider the space between the blue bars, the more **dramatic** the volitility. However, all the dark blue inside that "1 standard deviation" range tells us how many games were in that range. You can see that there are a _lot_ of games covered inside the two cyan bars.
#
# To be precise, the pecentage of games within 1 standard deviation of the average fantasy score is:

# %%
df_games_within_one_std = df.where(df.CustFPts >= (df_avg - df_std)).where(df.CustFPts <= (df_avg + df_std)).G.count() / df.G.count()
print("{0:.0%}".format(df_games_within_one_std))
# Out:
# 65%

# %% [markdown]
# The closer to `50%` *and* the *wider* the 1 standard deviation range, the **more** volitile the fantasy score is.
#
# Another way to say all this information is:

# %%
print("There is a {0:.0%} chance of my D/ST scoring {1:.2f} ± {2:.2f} points".format(df_games_within_one_std, df_avg, df_std))
# Out:
# There is a 65% chance of my D/ST scoring 6.04 ± 8.92 points

# %% [markdown]
# That means, as a GM, D/ST is a big risk-reward player. It could really hurt you on a bad week, but _really_ help you on a good week. That _doesn't_ tell us, though, how _likely_ you are to get a bad week versus a good week.
#
# However, we're used to that same meta with another position, the QB.

# %%
qb_avg = qb_df.CustFPts.mean()
qb_std = qb_df.CustFPts.std()
qb_within_bd_games = qb_df.where(qb_df.CustFPts >= (qb_avg - qb_std)).where(qb_df.CustFPts <= (qb_avg + qb_std)).G.count() / qb_df.G.count()
qb_df.CustFPts.hist()
plt.title("QB Custom Playing-for-Keeps Scoring")
plt.vlines([qb_avg, qb_avg + qb_std, qb_avg - qb_std], 0, 1000, ['r', 'c', 'c'], ['dashed', 'dashdot', 'dashdot'])
plt.xlabel("Score")
plt.ylabel("# of player games")
print("{0:.0%} of games are within 1 standard deviation".format(qb_within_bd_games))
print("There is a {0:.0%} chance of my QB scoring {1:.2f} ± {2:.2f} points".format(qb_within_bd_games, qb_avg, qb_std))
# Out:
# 65% of games are within 1 standard deviation
# There is a 65% chance of my QB scoring 24.41 ± 14.74 points

# %% [markdown]
# # stats-appendix

# %%
pd.options.display.max_rows = 500
print('"count" means the number of games in the table below... sorry')
df.groupby(by=["Team", "Season"])[["CustFPts"]].describe()
# Out:
# "count" means the number of games in the table below... sorry
#                   CustFPts
#                      count       mean        std   min   25%   50%   75%   max
# Team       Season
# Bears      2018       15.0  13.200000  10.303952  -7.0  10.5  13.0  18.0  32.0
#            2019       15.0   7.666667   7.384024  -3.0   1.5   7.0  11.5  21.0
#            2020       15.0   6.533333   7.327703 -10.0   3.0   6.0  11.5  19.0
#            2021       15.0   4.466667   8.609519 -10.0  -2.5   5.0  10.0  22.0
#            2022       15.0   1.933333   7.923443 -10.0  -4.5   0.0   9.0  14.0
#            2023       15.0   6.666667  10.708252  -9.0  -2.0   7.0  15.5  23.0
# Bengals    2018       15.0   2.200000   9.792125 -10.0  -5.5   2.0   9.0  24.0
#            2019       15.0   2.600000   7.566845  -8.0  -1.5   2.0   6.0  21.0
#            2020       15.0   1.866667   7.029191 -10.0  -3.5   5.0   7.5  11.0
#            2021       15.0   7.066667   8.362046  -8.0   2.0   5.0  13.0  23.0
#            2022       15.0   5.866667   5.617151  -3.0   1.5   6.0   8.5  18.0
#            2023       15.0   6.733333   7.004760  -4.0   2.0   7.0  10.5  18.0
# Bills      2018       15.0   5.133333   9.241727  -8.0  -0.5   5.0  12.0  21.0
#            2019       15.0  10.066667   6.638273  -2.0   8.0  10.0  13.0  22.0
#            2020       15.0   5.533333   8.052211 -10.0   0.5   4.0  11.5  20.0
#            2021       15.0   9.800000  11.365361 -10.0   3.5  11.0  15.5  31.0
#            2022       15.0  10.000000   7.837638  -3.0   3.5  11.0  14.0  23.0
#            2023       15.0   9.466667  11.044499  -6.0   4.5   8.0  13.5  38.0
# Broncos    2018       15.0   8.000000   8.783101  -2.0   1.5   7.0  10.0  34.0
#            2019       15.0   7.933333   8.455486  -4.0   5.0   7.0   9.5  33.0
#            2020       15.0   2.400000   8.390471 -10.0  -2.0   1.0   6.5  18.0
#            2021       15.0   9.800000   9.049073  -3.0   3.0   9.0  14.5  29.0
#            2022       15.0   7.666667   8.457175 -10.0   2.0   8.0  13.5  20.0
#            2023       15.0   5.600000   7.881262  -8.0   1.5   7.0   9.0  18.0
# Browns     2018       15.0   4.733333   6.818742  -7.0  -1.5   8.0  10.0  14.0
#            2019       15.0   5.266667   9.098404  -8.0  -2.5   6.0   9.5  22.0
#            2020       15.0   3.533333   9.760464  -8.0  -5.0   1.0  12.5  22.0
#            2021       15.0   6.533333  10.259955  -8.0  -1.5   9.0  14.0  24.0
#            2022       15.0   4.933333  10.180280  -9.0  -3.0   4.0   7.5  27.0
#            2023       15.0   8.200000  10.115052 -10.0   3.0   8.0  12.5  31.0
# Buccaneers 2018       15.0   1.266667   8.497619  -9.0  -5.0   0.0   6.0  18.0
#            2019       15.0   3.666667   9.626353  -9.0  -3.5   4.0   7.5  25.0
#            2020       15.0   7.666667   9.263343  -9.0   2.5   7.0  12.5  25.0
#            2022       15.0   4.266667   7.382089 -10.0   2.0   5.0   8.5  16.0
#            2023       15.0   8.733333   9.989042  -4.0   1.5   7.0  14.5  26.0
# ers        2018       15.0   2.733333   8.379112  -8.0  -3.0   2.0   7.5  23.0
#            2019       15.0  11.200000  10.462177 -10.0   4.5  11.0  19.0  26.0
#            2020       15.0   4.866667  10.140912  -8.0  -4.0   4.0  12.5  25.0
#            2021       15.0   5.600000   7.452708  -4.0  -0.5   6.0  10.5  22.0
#            2022       15.0  12.266667   8.639334  -7.0   9.0  14.0  18.0  25.0
#            2023       15.0  10.400000   7.762547  -2.0   5.5  11.0  16.0  24.0

# %%
avg = df.FPts.mean()
std = df.FPts.std()
df.FPts.hist()
plt.title("D/ST Standard Scoring")
plt.vlines([avg, avg + std, avg - std], 0, 1000, ['r', 'c', 'c'], ['dashed', 'dashdot', 'dashdot'])
plt.xlabel("Score")
plt.ylabel("# of player games")
print("avg: {:.1f}, standard deviation: {:.1f}".format(avg, std))
print("{} games at 21+ Fantasy Points (roughly {:.1%} of games)".format(df.where(df.FPts > 20).G.count(), df.where(df.FPts > 20).G.count() / df.G.count()))
print("{0:.0%} of games are within 1 standard deviation of the average fantasy score".format(df.where(df.FPts >= (avg - std)).where(df.FPts <= (avg + std)).G.count() / df.G.count()))
# Out:
# avg: 5.9, standard deviation: 4.4
# 25 games at 21+ Fantasy Points (roughly 0.9% of games)
# 74% of games are within 1 standard deviation of the average fantasy score

# %%
avg = df.CustFPts.mean()
std = df.CustFPts.std()
df.CustFPts.hist()
plt.title("D/ST Custom Playing-for-Keeps Scoring")
plt.vlines([avg, avg + std, avg - std], 0, 800, ['r', 'c', 'c'], ['dashed', 'dashdot', 'dashdot'])
plt.xlabel("Score")
plt.ylabel("# of player games")
print("avg: {:.1f}, standard deviation: {:.1f}".format(avg, std))
print("{} games at 21+ Fantasy Points (roughly {:.1%} of games)".format(df.where(df.CustFPts > 20).G.count(), df.where(df.CustFPts > 20).G.count() / df.G.count()))
print("{0:.0%} of games are within 1 standard deviation of the average fantasy score".format(df.where(df.CustFPts >= (avg - std)).where(df.CustFPts <= (avg + std)).G.count() / df.G.count()))
# Out:
# avg: 6.0, standard deviation: 8.9
# 183 games at 21+ Fantasy Points (roughly 6.4% of games)
# 65% of games are within 1 standard deviation of the average fantasy score

# %%
avg = wr_df.FPts.mean()
std = wr_df.FPts.std()
wr_df.FPts.hist()
plt.title("WR Standard Scoring (used in PK league)")
plt.vlines([avg, avg + std, avg - std], 0, 2000, ['r', 'c', 'c'], ['dashed', 'dashdot', 'dashdot'])
plt.xlabel("Score")
plt.ylabel("# of player games")
print("avg: {:.1f}, standard deviation: {:.1f}".format(avg, std))
print("{} games at 21+ Fantasy Points (roughly {:.1%} of games)".format(wr_df.where(wr_df.FPts > 20).G.count(), wr_df.where(wr_df.FPts > 20).G.count() / wr_df.G.count()))
print("{0:.0%} of games are within 1 standard deviation of the average fantasy score".format(wr_df.where(wr_df.FPts >= (avg - std)).where(wr_df.FPts <= (avg + std)).G.count() / wr_df.G.count()))
# Out:
# avg: 10.8, standard deviation: 5.5
# 324 games at 21+ Fantasy Points (roughly 6.8% of games)
# 74% of games are within 1 standard deviation of the average fantasy score

# %%
avg = rb_df.FPts.mean()
std = rb_df.FPts.std()
rb_df.FPts.hist()
plt.title("RB Standard Scoring (used in PK league)")
plt.vlines([avg, avg + std, avg - std], 0, 2000, ['r', 'c', 'c'], ['dashed', 'dashdot', 'dashdot'])
plt.xlabel("Score")
plt.ylabel("# of player games")
print("avg: {:.1f}, standard deviation: {:.1f}".format(avg, std))
print("{} games at 21+ Fantasy Points (roughly {:.1%} of games)".format(rb_df.where(rb_df.FPts > 20).G.count(), rb_df.where(rb_df.FPts > 20).G.count() / rb_df.G.count()))
print("{0:.0%} of games are within 1 standard deviation of the average fantasy score".format(rb_df.where(rb_df.FPts >= (avg - std)).where(rb_df.FPts <= (avg + std)).G.count() / rb_df.G.count()))
# Out:
# avg: 10.2, standard deviation: 6.8
# 451 games at 21+ Fantasy Points (roughly 9.4% of games)
# 75% of games are within 1 standard deviation of the average fantasy score

# %%
avg = qb_df.CustFPts.mean()
std = qb_df.CustFPts.std()
qb_df.CustFPts.hist()
plt.title("QB Custom Playing-for-Keeps Scoring")
plt.vlines([avg, avg + std, avg - std], 0, 1000, ['r', 'c', 'c'], ['dashed', 'dashdot', 'dashdot'])
plt.xlabel("Score")
plt.ylabel("# of player games")
print("avg: {:.1f}, standard deviation: {:.1f}".format(avg, std))
print("{} games at 21+ Fantasy Points (roughly {:.1%} of games)".format(qb_df.where(qb_df.CustFPts > 20).G.count(), qb_df.where(qb_df.CustFPts > 20).G.count() / qb_df.G.count()))
print("{0:.0%} of games are within 1 standard deviation of the average fantasy score".format(qb_df.where(qb_df.CustFPts >= (avg - std)).where(qb_df.CustFPts <= (avg + std)).G.count() / qb_df.G.count()))
# Out:
# avg: 24.4, standard deviation: 14.7
# 2124 games at 21+ Fantasy Points (roughly 62.5% of games)
# 65% of games are within 1 standard deviation of the average fantasy score

# %%
qb_df.where(qb_df.Season == qb_df.Season.max()).groupby('Player').CustFPts.sum().sort_values(ascending=False).head(10)
# Out:
# Player
# Josh Allen         532.72
# Jalen Hurts        509.54
# Dak Prescott       502.18
# Brock Purdy        487.00
# Patrick Mahomes    463.62
# Jared Goff         458.66
# Tua Tagovailoa     458.46
# Lamar Jackson      458.18
# Jordan Love        454.68
# Baker Mayfield     435.42
# Name: CustFPts, dtype: float64

# %%
rb_df.where(rb_df.Season == rb_df.Season.max()).groupby('Player').FPts.sum().sort_values(ascending=False).head(15)
# Out:
# Player
# Christian McCaffrey    315.2
# Raheem Mostert         242.7
# Kyren Williams         192.9
# Rachaad White          190.0
# Travis Etienne         187.9
# Derrick Henry          181.6
# James Cook             179.1
# Jahmyr Gibbs           176.8
# Joe Mixon              174.6
# David Montgomery       166.7
# Breece Hall            163.5
# Bijan Robinson         160.9
# Gus Edwards            157.9
# D'Andre Swift          153.4
# Saquon Barkley         152.7
# Name: FPts, dtype: float64

# %%
wr_df.where(wr_df.Season == wr_df.Season.max()).groupby('Player').FPts.sum().sort_values(ascending=False).head(10)
# Out:
# Player
# Tyreek Hill          235.6
# CeeDee Lamb          216.5
# Mike Evans           189.5
# A.J. Brown           175.7
# Amon-Ra St. Brown    173.3
# Deebo Samuel         165.6
# Keenan Allen         164.9
# Puka Nacua           156.9
# D.J. Moore           150.0
# Ja'Marr Chase        146.9
# Name: FPts, dtype: float64

# %%
df.where(df.Season == df.Season.max()).groupby('Team').ProposedCustFPts.sum().sort_values(ascending=False).head(10)
# Out:
# Team
# Ravens        185.0
# Cowboys       160.0
# ers           156.0
# Dolphins      147.0
# Bills         142.0
# Chiefs        140.0
# Raiders       140.0
# Steelers      138.0
# Buccaneers    133.0
# Vikings       131.0
# Name: ProposedCustFPts, dtype: float64

# %%
qb_df.groupby(['Player','Season']).CustFPts.sum().sort_values(ascending=False).head(10)
# Out:
# Player           Season
# Patrick Mahomes  2018      675.34
#                  2020      627.90
#                  2022      622.70
# Lamar Jackson    2019      606.78
# Aaron Rodgers    2020      602.06
# Josh Allen       2020      600.50
#                  2022      582.06
# Deshaun Watson   2020      573.92
# Kyler Murray     2020      572.26
# Josh Allen       2021      571.82
# Name: CustFPts, dtype: float64

# %%
wr_df
# Out:
#               Player Team    G  Receiving - Target  Receiving - Rec  \
# 0        Tyreek Hill   KC  1.0                 8.0              7.0
# 1     DeSean Jackson   TB  1.0                 5.0              5.0
# 2       Kenny Stills  MIA  1.0                 5.0              4.0
# 3     Michael Thomas   NO  1.0                17.0             16.0
# 4         Mike Evans   TB  1.0                 7.0              7.0
# ...              ...  ...  ...                 ...              ...
# 4795    Deebo Samuel   SF  1.0                12.0              4.0
# 4796  Brandon Powell  MIN  1.0                 4.0              3.0
# 4797   Jaylen Waddle  MIA  1.0                 4.0              1.0
# 4798       Bo Melton   GB  1.0                 6.0              4.0
# 4799   Jalen Tolbert  DAL  1.0                 2.0              2.0
#
#       Receiving - Yard  Receiving - TD  Rushing - Att  Rushing - Yard  \
# 0                169.0             2.0            2.0             4.0
# 1                146.0             2.0            0.0             0.0
# 2                106.0             2.0            0.0             0.0
# 3                180.0             1.0            0.0             0.0
# 4                147.0             1.0            0.0             0.0
# ...                ...             ...            ...             ...
# 4795              47.0             0.0            2.0             7.0
# 4796              53.0             0.0            0.0             0.0
# 4797              50.0             0.0            1.0             2.0
# 4798              44.0             0.0            1.0             7.0
# 4799              51.0             0.0            0.0             0.0
#
#       Rushing - TD  FPts  FPts/G  Season  Week
# 0              0.0  29.3    29.3    2018     1
# 1              0.0  26.6    26.6    2018     1
# 2              0.0  22.6    22.6    2018     1
# 3              0.0  22.0    22.0    2018     1
# 4              0.0  20.7    20.7    2018     1
# ...            ...   ...     ...     ...   ...
# 4795           0.0   5.4     5.4    2023    16
# 4796           0.0   5.3     5.3    2023    16
# 4797           0.0   5.2     5.2    2023    16
# 4798           0.0   5.1     5.1    2023    16
# 4799           0.0   5.1     5.1    2023    16
#
# [4800 rows x 14 columns]

# %%
wr_df['FPts/Tgt'] = wr_df.FPts / wr_df['Receiving - Target']


wr_season_df_gb = wr_df.where(wr_df.Season == wr_df.Season.max()).where(wr_df['Receiving - Target'] != 0).rename(columns={'Receiving - Target': 'RecTgts'}).groupby('Player')
wr_season_df = wr_season_df_gb
wr_season_db = wr_season_df

max_total_recp = wr_season_df.RecTgts.sum().to_frame(name="total_recp").total_recp.max()
# weight = wr_season_db.size() / wr_season_db.size().max()
weight = wr_season_db.RecTgts.sum() / max_total_recp
temp_df = ((wr_season_db.FPts.sum() / wr_season_db.RecTgts.sum()) * (weight)).to_frame(name='weighted_pts_per_rec')
wrs_by_weight_points = temp_df.join(wr_season_db.FPts.sum().to_frame(name='total_pts')).join(wr_season_db.RecTgts.sum().to_frame(name='total_rec')).sort_values(by='weighted_pts_per_rec', ascending=False)
wrs_by_weight_points.head(36)
# Out:
#                      weighted_pts_per_rec  total_pts  total_rec
# Player
# Tyreek Hill                      1.560265      235.6      146.0
# CeeDee Lamb                      1.433775      216.5      151.0
# Mike Evans                       1.254967      189.5      115.0
# A.J. Brown                       1.163576      175.7      142.0
# Amon-Ra St. Brown                1.147682      173.3      138.0
# Deebo Samuel                     1.096689      165.6       80.0
# Keenan Allen                     1.092053      164.9      150.0
# Puka Nacua                       1.039073      156.9      117.0
# D.J. Moore                       0.993377      150.0       98.0
# Ja'Marr Chase                    0.972848      146.9      111.0
# Brandon Aiyuk                    0.968874      146.3       82.0
# DK Metcalf                       0.957616      144.6       96.0
# Stefon Diggs                     0.937748      141.6      113.0
# Amari Cooper                     0.930464      140.5       93.0
# DeVonta Smith                    0.899338      135.8       86.0
# Nico Collins                     0.878146      132.6       78.0
# Jordan Addison                   0.860927      130.0       77.0
# Courtland Sutton                 0.858940      129.7       82.0
# Chris Olave                      0.815232      123.1      114.0
# Michael Pittman Jr.              0.815232      123.1      126.0
# Davante Adams                    0.813245      122.8      128.0
# Jaylen Waddle                    0.807947      122.0       99.0
# George Pickens                   0.800000      120.8       66.0
# Jayden Reed                      0.773510      116.8       75.0
# Calvin Ridley                    0.762914      115.2       76.0
# DeAndre Hopkins                  0.749669      113.2       81.0
# Rashee Rice                      0.728477      110.0       84.0
# Adam Thielen                     0.727815      109.9      104.0
# Tank Dell                        0.719205      108.6       64.0
# Gabe Davis                       0.717881      108.4       58.0
# Jakobi Meyers                    0.694702      104.9       73.0
# Garrett Wilson                   0.684106      103.3      132.0
# Romeo Doubs                      0.678808      102.5       75.0
# Zay Flowers                      0.676159      102.1       91.0
# Justin Jefferson                 0.654305       98.8       67.0
# Terry McLaurin                   0.602649       91.0       91.0

# %%
rb_df
# Out:
#                      Player Team    G  Rushing - Att  Rushing - Yard  \
# 0              Alvin Kamara   NO  1.0            8.0            29.0
# 1              James Conner  PIT  1.0           31.0           135.0
# 2            Isaiah Crowell  NYJ  1.0           10.0           102.0
# 3                 Joe Mixon  CIN  1.0           17.0            95.0
# 4               Todd Gurley  LAR  1.0           20.0           108.0
# ...                     ...  ...  ...            ...             ...
# 4795           Alvin Kamara   NO  1.0            9.0            19.0
# 4796  Cordarrelle Patterson  ATL  1.0            7.0            26.0
# 4797          De'Von Achane  MIA  1.0            7.0            24.0
# 4798         Travis Etienne  JAC  1.0            6.0            12.0
# 4799          Tyler Goodson  IND  1.0            1.0            15.0
#
#       Rushing - TD  Receiving - Target  Receiving - Rec  Receiving - Yard  \
# 0              2.0                12.0              9.0             112.0
# 1              2.0                 6.0              5.0              57.0
# 2              2.0                 0.0              0.0               0.0
# 3              1.0                 7.0              5.0              54.0
# 4              0.0                 5.0              3.0              39.0
# ...            ...                 ...              ...               ...
# 4795           0.0                 6.0              5.0              16.0
# 4796           0.0                 2.0              2.0               7.0
# 4797           0.0                 3.0              1.0               7.0
# 4798           0.0                 3.0              3.0              19.0
# 4799           0.0                 2.0              1.0              15.0
#
#       Receiving - TD  FPts  FPts/G  Season  Week
# 0                1.0  32.1    32.1    2018     1
# 1                0.0  29.2    29.2    2018     1
# 2                0.0  22.2    22.2    2018     1
# 3                0.0  20.9    20.9    2018     1
# 4                1.0  20.7    20.7    2018     1
# ...              ...   ...     ...     ...   ...
# 4795             0.0   3.5     3.5    2023    16
# 4796             0.0   3.3     3.3    2023    16
# 4797             0.0   3.1     3.1    2023    16
# 4798             0.0   3.1     3.1    2023    16
# 4799             0.0   3.0     3.0    2023    16
#
# [4800 rows x 14 columns]

# %%
rb_season_df_gb = rb_df.where(rb_df.Season == rb_df.Season.max()).groupby('Player')
#rb_season_df = rb_season_df_gb.size().to_frame(name='num_games').join(rb_season_df_gb.FPts.sum())
rb_season_df = rb_season_df_gb
rb_season_db = rb_season_df

((rb_season_db.FPts.sum()) * (rb_season_db.size() / rb_season_db.size().max())).sort_values(ascending=False).head(20)
# Out:
# Player
# Christian McCaffrey    315.200000
# Raheem Mostert         242.700000
# Rachaad White          190.000000
# Travis Etienne         187.900000
# James Cook             179.100000
# Joe Mixon              174.600000
# Derrick Henry          157.386667
# Jahmyr Gibbs           153.226667
# Gus Edwards            147.373333
# Tony Pollard           146.100000
# D'Andre Swift          143.173333
# Kyren Williams         141.460000
# Bijan Robinson         139.446667
# David Montgomery       133.360000
# Breece Hall            130.800000
# Isiah Pacheco          127.746667
# Jerome Ford            127.213333
# Brian Robinson Jr.     125.666667
# Josh Jacobs            124.886667
# Saquon Barkley         122.160000
# dtype: float64

# %%
qb_pts_by_season = qb_df.groupby(['Player','Season']).CustFPts.sum().sort_values(ascending=False)
wr_pts_by_season = wr_df.groupby(['Player', 'Season']).FPts.sum().sort_values(ascending=False)

# %%
wr_pts_by_season
# Out:
# Player            Season
# Cooper Kupp       2021      257.4
# Tyreek Hill       2020      239.4
#                   2023      235.6
# Davante Adams     2020      225.0
# Justin Jefferson  2022      222.5
#                             ...
# Jalen Brooks      2023        3.9
# Tyquan Thornton   2023        3.9
# Dee Eskridge      2022        3.9
# Mack Hollins      2023        3.6
# Trent Taylor      2022        3.2
# Name: FPts, Length: 942, dtype: float64

# %%
wrs_by_weight_points.head(36).sum() / wrs_by_weight_points.sum()
# Out:
# weighted_pts_per_rec    0.581854
# total_pts               0.581854
# total_rec               0.616064
# dtype: float64

# %%
wrs_by_weight_points.head(24).sum() / wrs_by_weight_points.sum()
# Out:
# weighted_pts_per_rec    0.430446
# total_pts               0.430446
# total_rec               0.443656
# dtype: float64
